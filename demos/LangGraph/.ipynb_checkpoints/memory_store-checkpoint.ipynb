# %%
import uuid

from langgraph.store.memory import InMemoryStore

# %%
in_memory_store = InMemoryStore()

# %%
in_memory_store

# %%
user_id = "1"
namespace_for_memory = (user_id, "memories")
memory_id = str(uuid.uuid4())
memory = {"food_preference": "我喜欢吃牛肉。"}

# %%
in_memory_store.put(namespace_for_memory, memory_id, memory)

# %%
memories = in_memory_store.search(namespace_for_memory)
memories
# Out:
# [Item(namespace=['1', 'memories'], key='3606a0d2-cf92-423e-8e90-7bcfb8d4c322', value={'food_preference': '我喜欢吃牛肉。'}, created_at='2025-11-20T08:17:11.497682+00:00', updated_at='2025-11-20T08:17:11.497682+00:00', score=None)]

# %%
memories[-1].dict()
# Out:
# {'namespace': ['1', 'memories'],
#  'key': '3606a0d2-cf92-423e-8e90-7bcfb8d4c322',
#  'value': {'food_preference': '我喜欢吃牛肉。'},
#  'created_at': '2025-11-20T08:17:11.497682+00:00',
#  'updated_at': '2025-11-20T08:17:11.497682+00:00',
#  'score': None}
