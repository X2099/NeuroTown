# %%
from checkpoints import graph

# %%
graph

# %%
from langchain_core.runnables import RunnableConfig

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
graph.invoke({"foo": "", "bar": []}, config)
# Out:
# {'foo': 'b', 'bar': ['a', 'b']}

# %%
graph.get_state(config)
# Out:
# StateSnapshot(values={'foo': 'b', 'bar': ['a', 'b']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be26-64fe-8002-5f9e71791fe6'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-02T07:49:51.615513+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be1f-6e82-8001-dc081f12e3e9'}}, tasks=(), interrupts=())

# %%
config = {"configurable": {"thread_id": "1", "checkpoint_id": "1f0cf537-be1f-6e82-8001-dc081f12e3e9"}}

# %%
graph.get_state(config)
# Out:
# StateSnapshot(values={'foo': 'a', 'bar': ['a']}, next=('node_b',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f0cf537-be1f-6e82-8001-dc081f12e3e9'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-02T07:49:51.612889+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be1b-6092-8000-c6ada0a16171'}}, tasks=(PregelTask(id='0c35b9e6-c139-156b-5da3-6e73e245012c', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result={'foo': 'b', 'bar': ['b']}),), interrupts=())

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
list(graph.get_state_history(config))
# Out:
# [StateSnapshot(values={'foo': 'b', 'bar': ['a', 'b']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be26-64fe-8002-5f9e71791fe6'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-02T07:49:51.615513+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be1f-6e82-8001-dc081f12e3e9'}}, tasks=(), interrupts=()),
# ...

# %%
config = {"configurable": {"thread_id": "1", "checkpoint_id": "1f0cf537-be1b-6092-8000-c6ada0a16171"}}

# %%
graph.invoke(None, config)
# Out:
# {'foo': 'b', 'bar': ['a', 'b']}

# %%
list(graph.get_state_history({"configurable": {"thread_id": "1"}}))
# Out:
# [StateSnapshot(values={'foo': 'b', 'bar': ['a', 'b']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf592-7759-616b-8002-ce7ea1d280dc'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-02T08:30:26.954071+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf592-7756-6af6-8001-8ac01cd04921'}}, tasks=(), interrupts=()),
# ...

# %%
config =  {"configurable": {"thread_id": "1"}}
graph.update_state(config, {"foo": "666", "bar": ["c"]})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0cf613-b343-6878-8003-113c0078e122'}}

# %%
graph.get_state(config)
# Out:
# StateSnapshot(values={'foo': '666', 'bar': ['a', 'b', 'c']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf613-b343-6878-8003-113c0078e122'}}, metadata={'source': 'update', 'step': 3, 'parents': {}}, created_at='2025-12-02T09:28:16.054079+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf592-7759-616b-8002-ce7ea1d280dc'}}, tasks=(), interrupts=())

# %%
config = {"configurable": {"thread_id": "1", "checkpoint_id": "1f0cf537-be26-64fe-8002-5f9e71791fe6", "checkpoint_ns": ''}}
graph.update_state(config, {"foo": "777", "bar": ["x"]})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0cf621-cf1c-6443-8003-f7ca76807be8'}}

# %%
graph.get_state({"configurable": {"thread_id": "1"}})
# Out:
# StateSnapshot(values={'foo': '777', 'bar': ['a', 'b', 'x']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf621-cf1c-6443-8003-f7ca76807be8'}}, metadata={'source': 'update', 'step': 3, 'parents': {}}, created_at='2025-12-02T09:34:34.783648+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be26-64fe-8002-5f9e71791fe6'}}, tasks=(), interrupts=())

# %%
config = {"configurable": {"thread_id": "1", "checkpoint_id": "1f0cf537-be26-64fe-8002-5f9e71791fe6", "checkpoint_ns": ''}}
graph.update_state(config, {"foo": "777", "bar": ["x"]}, "node_a")
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0cf626-ff1e-61d0-8003-d77fdfcd404f'}}

# %%
graph.get_state({"configurable": {"thread_id": "1"}})
# Out:
# StateSnapshot(values={'foo': '777', 'bar': ['a', 'b', 'x']}, next=('node_b',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf626-ff1e-61d0-8003-d77fdfcd404f'}}, metadata={'source': 'update', 'step': 3, 'parents': {}}, created_at='2025-12-02T09:36:54.035297+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be26-64fe-8002-5f9e71791fe6'}}, tasks=(PregelTask(id='6070052c-90ed-e379-3730-9276b3ef096e', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
graph.get_state_history({"configurable": {"thread_id": "1"}})
# Out:
# <generator object Pregel.get_state_history at 0x00000259A4ACB740>

# %%
list(_)
# Out:
# [StateSnapshot(values={'foo': '777', 'bar': ['a', 'b', 'x']}, next=('node_b',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf626-ff1e-61d0-8003-d77fdfcd404f'}}, metadata={'source': 'update', 'step': 3, 'parents': {}}, created_at='2025-12-02T09:36:54.035297+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf537-be26-64fe-8002-5f9e71791fe6'}}, tasks=(PregelTask(id='6070052c-90ed-e379-3730-9276b3ef096e', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
graph.invoke(None, {"configurable": {"thread_id": "1"}})
# Out:
# {'foo': 'b', 'bar': ['a', 'b', 'x', 'b']}

# %%
list(graph.get_state_history({"configurable": {"thread_id": "1"}}))
# Out:
# [StateSnapshot(values={'foo': 'b', 'bar': ['a', 'b', 'x', 'b']}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf62d-8c55-6ac2-8004-69a252e6e07f'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-12-02T09:39:49.904249+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cf626-ff1e-61d0-8003-d77fdfcd404f'}}, tasks=(), interrupts=()),
# ...
